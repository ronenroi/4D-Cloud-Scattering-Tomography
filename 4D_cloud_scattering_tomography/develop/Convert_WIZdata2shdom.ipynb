# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.ticker as mtick
import matplotlib.patches as mpatches
import glob
import os
import pickle
import scipy
import math 
import scipy.io as sio

from scipy.optimize import curve_fit

# %%
def gamma_distribution(r,N,re,ve):
    C = ((re*ve)**(2-(1/ve)))/math.gamma((1/ve)-2)
    t = N*C*(r**((1/ve)-3))
    n = t*np.exp(-r/(re*ve))
    return n

def gamma_distribution_tofit(r,N,alpha,b):
    # defination from: https://web.archive.org/web/20171213043637/http://nit.colorado.edu/shdom/shdomdoc/
    a = (b**(alpha+1))*(N/(math.gamma(alpha+1)))#N = a Gamma(alpha+1)/ b^(alpha+1)
    n = a*(r**alpha)*np.exp(-r*b)
    return n

# %% [markdown]
# # LOAD DATA FROM ESHKOL APRIL 2020

# %%
# the parameters should be known in advance.
dx,dy,dz=(1e-3*10,1e-3*10,1e-3*10) # in km
nz_1 = 301
z_min_1 = 5*1e-3
z_max_1 = 3.005

nz_2 = 20
z_min_2 = 3.055
z_max_2 = 4.005
zgrid = np.concatenate((np.linspace(z_min_1, z_max_1 ,nz_1),np.linspace(z_min_2, z_max_2 ,nz_2)))

# %%
"""
Eshkol said:
The matrices named fncd are 4D: 128x128x100x33, where horizontal resolution is 50 m and vertical is 40 m. 
The 33 are the size distribution bins according to the same rd.mat vector that I gave you in all previous files.
Number concentration = sum( fncd ) on the forth dimension 
effective radius - re(i,j,k) = sum( rd^3*fncd(i,j,k) )/ sum( rd^2*fncd(i,j,k) )

So from the nc files (each contains x,y,z,time,rn,rd,p,rho,FNCD) I need to extract:
'FNCD': <class 'netCDF4._netCDF4.Variable'>
'rd': <class 'netCDF4._netCDF4.Variable'>

Each nc file has:
variable units shape
x m (128,)
y m (128,)
z m (100,)
time d (1,)
rn micron (33,)
rd micron (33,)
p mb (100,)
rho g/m3 (100,)
FNCD #/cm3/bin  (1, 33, 100, 128, 128)

To work with nc files you need netcdf4 packeg. 
So in the terminal do:
conda install -c anaconda netcdf4
then use: from netCDF4 import Dataset

What is FNCD?
I tried to read:
https://en.wikipedia.org/wiki/Raindrop_size_distribution

"""

import re
from tqdm import tqdm
from netCDF4 import Dataset

data_dir1 = '../synthetic_cloud_fields/WIZ_Clouds/BOMEX_1CLD_500CCN_10m_5sec'
data_dir = '../../../../wdata/clouds_from_weizmann/BOMEX_1CLD_500CCN_10m_5sec'

format_ = '*.com3D_int_2.nc'# load 
volumes_paths = sorted(glob.glob(data_dir + '/'+format_))
volume_stamps = [re.findall('_(\d*).com3D_int_2.nc', i)[0] for i in volumes_paths]
volume_stamps = [int(i) for i in volume_stamps]# convert to integer 

SHOWVOL = True # if true, show evrey volume
IF_SAVE_txt = True
PRINT_MICRO_PHYSICS = False
FIT_GAMMA = False # if it True, then fit gamma parameters with non-linear least squares fit
# BUT, the fit works strange, it doesn't fit good parameters to all vaxels. Some get huge values.
volumes_paths = l3 = [x for x in volumes_paths if x not in l2]
for file in volumes_paths:
    nc = Dataset(file)
    rd = nc.variables['rd'][:].data # units micron
    FNCD = np.squeeze(nc.variables['FNCD'][:].data) # units #/cm3/bin
    # note that the shape of FNCD is now (33, 100, 128, 128)
    
    # LWC:
    # what Eshkol explained with old data: rho - density kg/m^3  - you can use this to convert mixing ratio (LWC [g/kg]]) to liquid water density [g/m^-3]]
    # rho - density g/m3:
    rho = 1e6
    # Eshkol said: The rho in the output is of the whole voxel (so its mostly density of dry air and water vapor. 
    # I don't think you need it. For liquid water content you can take water density as constant of  1 g/cm^3.
    # rho = nc.variables['rho'][:].data
    
    # ----------------------------------------------------------------------------------------
    # ----------------------------------------------------------------------------------------
    # ----------------------------------------------------------------------------------------

    DOPC = FNCD# distribution of droplets consintration, it is given as histogram
    e_DOPC = DOPC
    e_rd = rd[:,np.newaxis, np.newaxis, np.newaxis]
    # ---------------------------------------------
    Dx = np.diff(rd)[:, np.newaxis, np.newaxis, np.newaxis]
    DOPC = DOPC[:-1,...]/Dx # it is the PDF
    rd = rd[:-1, np.newaxis, np.newaxis, np.newaxis]

    #---------------------------------------------
    # calculate reff, veff, LWC from the FNCD (here it doesn't assume gamma distribution):
    reff3D = np.trapz(DOPC*rd**3,rd, axis=0)/np.trapz(DOPC*rd**2,rd, axis=0)
    veff3D = np.trapz(((rd-reff3D)**2)*(rd**2)*DOPC,rd, axis=0)/(reff3D**2*np.trapz(DOPC*rd**2,rd, axis=0))
    LWC3D = (1e-12)*(4/3)*np.pi*rho*np.trapz((rd**3)*DOPC,rd, axis=0)
    # above it uses integral of the PDF, below it is as Eshkol suggested, just to use sum:
    # I think the integral is better choice espesialy using np.trapz, but I will use the sum as Yoav told to doas Eshkol instructed.
    e_reff3D = np.sum( e_rd**3*e_DOPC , axis=0)/ np.sum( e_rd**2*e_DOPC , axis=0)
    e_veff3D = np.sum( ((e_rd-e_reff3D)**2)*(e_rd**2)*e_DOPC , axis=0)/ np.sum( e_reff3D**2*e_DOPC*e_rd**2 , axis=0)
    e_LWC3D = (1e-12)*(4/3)*np.pi*rho*np.sum((e_rd**3)*e_DOPC, axis=0)
    # units of rho are g/m^3, of DOPC are #/cm3/um, of r um. The units of the result LWC are [g/m^3]
    NC3D = np.sum(DOPC*Dx, axis=0)# total consintration

    # avoide nans:
    e_LWC3D = np.nan_to_num(e_LWC3D)
    e_reff3D = np.nan_to_num(e_reff3D)
    e_veff3D = np.nan_to_num(e_veff3D)

    LWC3D = np.nan_to_num(LWC3D)
    reff3D = np.nan_to_num(reff3D)
    veff3D = np.nan_to_num(veff3D)

    # here the 3d shape is (100, 128, 128)
    RE = np.transpose(e_reff3D, (2, 1, 0))
    VE = np.transpose(e_veff3D, (2, 1, 0))
    LWC = np.transpose(e_LWC3D, (2, 1, 0))
    NCT = np.transpose(NC3D, (2, 1, 0))
    # here the 3d shape is (128, 128,100)
    
    # this is a good place to filter voxels.
    # Eshkol said voxels with LWC < 0.01 can be considered as not cloudy ones.
    lwc_treshold = 0.01 # [g/m^3]
    # In addition, I want to filter voxels with NC<1.
    NC_treshold = 1
    RE[LWC<lwc_treshold]  = 0
    VE[LWC<lwc_treshold]  = 0
    NCT[LWC<lwc_treshold] = 0
    LWC[LWC<lwc_treshold] = 0
    
    RE[NCT<NC_treshold]  = 0
    VE[NCT<NC_treshold]  = 0
    LWC[NCT<NC_treshold] = 0
    NCT[NCT<NC_treshold] = 0
    
    # re treshold:
    re_treshold = 35
    # VE[RE>re_treshold]  = 0
    # LWC[RE>re_treshold] = 0
    # NCT[RE>re_treshold] = 0
    RE[RE>re_treshold]  = re_treshold
        
    re_treshold = 1
    # VE[RE>re_treshold]  = 0
    # LWC[RE>re_treshold] = 0
    # NCT[RE>re_treshold] = 0
    RE[RE<re_treshold]  = re_treshold
    # ve treshold:
    ve_treshold = 0.2
    # LWC[VE>ve_treshold] = 0
    # NCT[VE>ve_treshold] = 0
    # RE[VE>ve_treshold]  = 0
    VE[VE>ve_treshold]  = ve_treshold
    ve_treshold = 0.02
    # LWC[VE<ve_treshold] = 0
    # NCT[VE<ve_treshold] = 0
    # RE[VE<ve_treshold]  = 0    
    VE[VE<ve_treshold]  = ve_treshold

    # fit gamma:
    FIT_GAMMA = False
    if(FIT_GAMMA):
        
        indxs = np.argwhere(LWC > 0)# cloudy voxel indexes
        for vox_indx in tqdm(indxs):
            DOPC_voxel = DOPC[:,vox_indx[2],vox_indx[1],vox_indx[0]] # distribution of droplets consintration 
            # the order vox_indx[2],vox_indx[1],vox_indx[0] is because x = np.transpose(x, (2, 1, 0))          
            try:
                PRINT_MICRO_PHYSICS = False
                rd_ = np.squeeze(rd)
                popt, pcov = curve_fit(gamma_distribution_tofit, rd_, DOPC_voxel)
                fited_gamma = gamma_distribution_tofit(rd_, *popt)
                fit_reff = np.trapz(fited_gamma*rd_**3,rd_, axis=0)/np.trapz(fited_gamma*rd_**2,rd_, axis=0)
                fit_veff = np.trapz(((rd_-fit_reff)**2)*(rd_**2)*fited_gamma,rd_, axis=0)/(fit_reff**2*np.trapz(fited_gamma*rd_**2,rd_, axis=0))
                fit_LWC = (1e-12)*(4/3)*np.pi*rho*np.trapz((rd_**3)*fited_gamma,rd_, axis=0)
                if(np.isnan(fit_reff) or np.isnan(fit_veff) or np.isnan(fit_LWC)):
                    continue
                
                if(fit_reff>re_treshold or fit_LWC<lwc_treshold or popt[0] < NC_treshold):
                    continue
                    
                if(PRINT_MICRO_PHYSICS):
                    print("fited LWC = {} [g/m^3]".format(fit_LWC))
                    print("fited reff = {} [um]".format(fit_reff))
                    print("fited veff = {}\n".format(fit_veff))
                    
                RE[vox_indx[0],vox_indx[1],vox_indx[2]]  = fit_reff
                VE[vox_indx[0],vox_indx[1],vox_indx[2]]  = fit_veff
                LWC[vox_indx[0],vox_indx[1],vox_indx[2]] = fit_LWC 
            except:
                print("Optimal parameters not found.\It will uses original parameters:")
                print("calculated LWC = {} [g/m^3]".format(LWC[vox_indx[0],vox_indx[1],vox_indx[2]]))
                print("calculated reff = {} [um]".format(RE[vox_indx[0],vox_indx[1],vox_indx[2]]))
                print("calculated veff = {}".format(VE[vox_indx[0],vox_indx[1],vox_indx[2]]))
    
    
    # do the padding here. Pad with zeros on the sides
    npad = ((1,1),(1,1),(0,0))
    LWC = np.pad(LWC, pad_width=npad, mode='constant', constant_values=0.0)
    NCT = np.pad(NCT, pad_width=npad, mode='constant', constant_values=0.0)
    RE = np.pad(RE, pad_width=npad, mode='constant', constant_values=0.0)
    VE = np.pad(VE, pad_width=npad, mode='constant', constant_values=0.0)
    
    if(IF_SAVE_txt):
        comment_line = "Data from Eshkol Itan"
        original_name = os.path.basename(file)
        file_name = original_name.split('.')[0]+'.txt'
        file_name = os.path.join(data_dir1,file_name)
        print('saving {}'.format(file_name))
        
        # print RE min max and VE nim max:
        m=RE[RE>0]
        print("RE MIN = {}".format(m.min()))
        print("RE MAX = {}".format(RE.max()))

        m=VE[VE>0]
        print("VE MIN = {}".format(m.min()))
        print("VE MAX = {}".format(VE.max()))
        # --------finish to print RE min max and VE nim max:
        

        np.savetxt(file_name, X=np.array([RE.shape]), fmt='%d', header=comment_line)
        f = open(file_name, 'ab') 
        
        
        np.savetxt(f, X=np.concatenate((np.array([dx, dy]), zgrid)).reshape(1,-1), fmt='%2.3f')
        nx, ny, nz = RE.shape
        totext_lwc = LWC
        totext_reff = RE
        totext_veff = VE
        y, x, z = np.meshgrid(range(ny), range(nx), range(nz))
        
        data = np.vstack((x.ravel(), y.ravel(), z.ravel(), totext_lwc.ravel(), totext_reff.ravel(), totext_veff.ravel())).T
        #delete unnecessary rows
        mask = LWC.ravel() > 0
        data = data[mask,...]
        np.savetxt(f, X=data, fmt='%d %d %d %.5f %.3f %.5f')        
        f.close()  
        
        # save only RE,VE for visualization in matlab:
        file_name = original_name.split('.')[0]+'.mat'
        file_name = os.path.join(data_dir1,file_name)
        # sio.savemat(file_name, dict(lwc=LWC,reff=RE,veff=VE,dx=dx,dy=dy,dz=dz),)  
        # print("saving .mat file to: {}\n\n".format(file_name))
        
        
            
# in pyshdom liquid water content lwc is of units (g/m^3).
# Out:
# /home/roironen/anaconda3/envs/pyshdom/lib/python3.7/site-packages/ipykernel_launcher.py:81: RuntimeWarning: invalid value encountered in true_divide
# /home/roironen/anaconda3/envs/pyshdom/lib/python3.7/site-packages/ipykernel_launcher.py:86: RuntimeWarning: invalid value encountered in true_divide
# saving ../synthetic_cloud_fields/WIZ_Clouds/BOMEX_1CLD_500CCN_10m_5sec/BOMEX_512x320_500CCN_10m_R100_invL_5sec_micro_512_0000006200.txt
# RE MIN = 1.0
# RE MAX = 35.0
# VE MIN = 0.019999999552965164
# VE MAX = 0.20000000298023224
# saving .mat file to: ../synthetic_cloud_fields/WIZ_Clouds/BOMEX_1CLD_500CCN_10m_5sec/BOMEX_512x320_500CCN_10m_R100_invL_5sec_micro_512_0000006200.mat
#
#
# saving ../synthetic_cloud_fields/WIZ_Clouds/BOMEX_1CLD_500CCN_10m_5sec/BOMEX_512x320_500CCN_10m_R100_invL_5sec_micro_512_0000006210.txt
# RE MIN = 1.0
# RE MAX = 16.084632873535156
# VE MIN = 0.019999999552965164
# VE MAX = 0.20000000298023224
# saving .mat file to: ../synthetic_cloud_fields/WIZ_Clouds/BOMEX_1CLD_500CCN_10m_5sec/BOMEX_512x320_500CCN_10m_R100_invL_5sec_micro_512_0000006210.mat
#
#
# saving ../synthetic_cloud_fields/WIZ_Clouds/BOMEX_1CLD_500CCN_10m_5sec/BOMEX_512x320_500CCN_10m_R100_invL_5sec_micro_512_0000006220.txt
# RE MIN = 1.0
# RE MAX = 16.123641967773438
# VE MIN = 0.019999999552965164
# VE MAX = 0.20000000298023224
# saving .mat file to: ../synthetic_cloud_fields/WIZ_Clouds/BOMEX_1CLD_500CCN_10m_5sec/BOMEX_512x320_500CCN_10m_R100_invL_5sec_micro_512_0000006220.mat
#
#
# saving ../synthetic_cloud_fields/WIZ_Clouds/BOMEX_1CLD_500CCN_10m_5sec/BOMEX_512x320_500CCN_10m_R100_invL_5sec_micro_512_0000006230.txt
# RE MIN = 1.0
# RE MAX = 16.427125930786133
# VE MIN = 0.019999999552965164
# VE MAX = 0.20000000298023224
# saving .mat file to: ../synthetic_cloud_fields/WIZ_Clouds/BOMEX_1CLD_500CCN_10m_5sec/BOMEX_512x320_500CCN_10m_R100_invL_5sec_micro_512_0000006230.mat
#
#
# saving ../synthetic_cloud_fields/WIZ_Clouds/BOMEX_1CLD_500CCN_10m_5sec/BOMEX_512x320_500CCN_10m_R100_invL_5sec_micro_512_0000006240.txt
# RE MIN = 1.0
# RE MAX = 15.839228630065918
# VE MIN = 0.019999999552965164
# VE MAX = 0.20000000298023224
# saving .mat file to: ../synthetic_cloud_fields/WIZ_Clouds/BOMEX_1CLD_500CCN_10m_5sec/BOMEX_512x320_500CCN_10m_R100_invL_5sec_micro_512_0000006240.mat
#
#
# saving ../synthetic_cloud_fields/WIZ_Clouds/BOMEX_1CLD_500CCN_10m_5sec/BOMEX_512x320_500CCN_10m_R100_invL_5sec_micro_512_0000006250.txt
# RE MIN = 1.0
# RE MAX = 15.94438648223877
# VE MIN = 0.019999999552965164
# VE MAX = 0.20000000298023224
# saving .mat file to: ../synthetic_cloud_fields/WIZ_Clouds/BOMEX_1CLD_500CCN_10m_5sec/BOMEX_512x320_500CCN_10m_R100_invL_5sec_micro_512_0000006250.mat
#
#
# saving ../synthetic_cloud_fields/WIZ_Clouds/BOMEX_1CLD_500CCN_10m_5sec/BOMEX_512x320_500CCN_10m_R100_invL_5sec_micro_512_0000006260.txt
# RE MIN = 1.0
# RE MAX = 16.114694595336914
# VE MIN = 0.019999999552965164
# VE MAX = 0.20000000298023224
# saving .mat file to: ../synthetic_cloud_fields/WIZ_Clouds/BOMEX_1CLD_500CCN_10m_5sec/BOMEX_512x320_500CCN_10m_R100_invL_5sec_micro_512_0000006260.mat
#
#
# saving ../synthetic_cloud_fields/WIZ_Clouds/BOMEX_1CLD_500CCN_10m_5sec/BOMEX_512x320_500CCN_10m_R100_invL_5sec_micro_512_0000006270.txt
# RE MIN = 1.0
# RE MAX = 16.077512741088867
# VE MIN = 0.019999999552965164
# VE MAX = 0.20000000298023224
# saving .mat file to: ../synthetic_cloud_fields/WIZ_Clouds/BOMEX_1CLD_500CCN_10m_5sec/BOMEX_512x320_500CCN_10m_R100_invL_5sec_micro_512_0000006270.mat
#
#
# saving ../synthetic_cloud_fields/WIZ_Clouds/BOMEX_1CLD_500CCN_10m_5sec/BOMEX_512x320_500CCN_10m_R100_invL_5sec_micro_512_0000006280.txt
# RE MIN = 1.0
# RE MAX = 15.907228469848633
# VE MIN = 0.019999999552965164
# VE MAX = 0.20000000298023224
# saving .mat file to: ../synthetic_cloud_fields/WIZ_Clouds/BOMEX_1CLD_500CCN_10m_5sec/BOMEX_512x320_500CCN_10m_R100_invL_5sec_micro_512_0000006280.mat
#
#
# saving ../synthetic_cloud_fields/WIZ_Clouds/BOMEX_1CLD_500CCN_10m_5sec/BOMEX_512x320_500CCN_10m_R100_invL_5sec_micro_512_0000006290.txt
# RE MIN = 1.0
# RE MAX = 15.610201835632324
# VE MIN = 0.019999999552965164
# VE MAX = 0.20000000298023224
# saving .mat file to: ../synthetic_cloud_fields/WIZ_Clouds/BOMEX_1CLD_500CCN_10m_5sec/BOMEX_512x320_500CCN_10m_R100_invL_5sec_micro_512_0000006290.mat
#
#
# saving ../synthetic_cloud_fields/WIZ_Clouds/BOMEX_1CLD_500CCN_10m_5sec/BOMEX_512x320_500CCN_10m_R100_invL_5sec_micro_512_0000006300.txt
# RE MIN = 1.0
# RE MAX = 16.120569229125977
# VE MIN = 0.019999999552965164
# VE MAX = 0.20000000298023224
# saving .mat file to: ../synthetic_cloud_fields/WIZ_Clouds/BOMEX_1CLD_500CCN_10m_5sec/BOMEX_512x320_500CCN_10m_R100_invL_5sec_micro_512_0000006300.mat
#
#
# saving ../synthetic_cloud_fields/WIZ_Clouds/BOMEX_1CLD_500CCN_10m_5sec/BOMEX_512x320_500CCN_10m_R100_invL_5sec_micro_512_0000006310.txt
# RE MIN = 1.0
# RE MAX = 16.8702392578125
# VE MIN = 0.019999999552965164
# VE MAX = 0.20000000298023224
# saving .mat file to: ../synthetic_cloud_fields/WIZ_Clouds/BOMEX_1CLD_500CCN_10m_5sec/BOMEX_512x320_500CCN_10m_R100_invL_5sec_micro_512_0000006310.mat
#
#
# saving ../synthetic_cloud_fields/WIZ_Clouds/BOMEX_1CLD_500CCN_10m_5sec/BOMEX_512x320_500CCN_10m_R100_invL_5sec_micro_512_0000006320.txt
# RE MIN = 1.0
# RE MAX = 17.553987503051758
# VE MIN = 0.019999999552965164
# VE MAX = 0.20000000298023224
# saving .mat file to: ../synthetic_cloud_fields/WIZ_Clouds/BOMEX_1CLD_500CCN_10m_5sec/BOMEX_512x320_500CCN_10m_R100_invL_5sec_micro_512_0000006320.mat
#
#
# saving ../synthetic_cloud_fields/WIZ_Clouds/BOMEX_1CLD_500CCN_10m_5sec/BOMEX_512x320_500CCN_10m_R100_invL_5sec_micro_512_0000006330.txt
# RE MIN = 1.0
# RE MAX = 16.368654251098633
# VE MIN = 0.019999999552965164
# VE MAX = 0.20000000298023224
# saving .mat file to: ../synthetic_cloud_fields/WIZ_Clouds/BOMEX_1CLD_500CCN_10m_5sec/BOMEX_512x320_500CCN_10m_R100_invL_5sec_micro_512_0000006330.mat
#
#
# saving ../synthetic_cloud_fields/WIZ_Clouds/BOMEX_1CLD_500CCN_10m_5sec/BOMEX_512x320_500CCN_10m_R100_invL_5sec_micro_512_0000006340.txt
# RE MIN = 1.0
# RE MAX = 16.064735412597656
# VE MIN = 0.019999999552965164
# VE MAX = 0.20000000298023224
# saving .mat file to: ../synthetic_cloud_fields/WIZ_Clouds/BOMEX_1CLD_500CCN_10m_5sec/BOMEX_512x320_500CCN_10m_R100_invL_5sec_micro_512_0000006340.mat
#
#
# saving ../synthetic_cloud_fields/WIZ_Clouds/BOMEX_1CLD_500CCN_10m_5sec/BOMEX_512x320_500CCN_10m_R100_invL_5sec_micro_512_0000006350.txt
# RE MIN = 1.0
# RE MAX = 16.111570358276367
# VE MIN = 0.019999999552965164
# VE MAX = 0.20000000298023224
# saving .mat file to: ../synthetic_cloud_fields/WIZ_Clouds/BOMEX_1CLD_500CCN_10m_5sec/BOMEX_512x320_500CCN_10m_R100_invL_5sec_micro_512_0000006350.mat
#
#
# saving ../synthetic_cloud_fields/WIZ_Clouds/BOMEX_1CLD_500CCN_10m_5sec/BOMEX_512x320_500CCN_10m_R100_invL_5sec_micro_512_0000006360.txt
# RE MIN = 1.0
# RE MAX = 15.932173728942871
# VE MIN = 0.019999999552965164
# VE MAX = 0.20000000298023224
# saving .mat file to: ../synthetic_cloud_fields/WIZ_Clouds/BOMEX_1CLD_500CCN_10m_5sec/BOMEX_512x320_500CCN_10m_R100_invL_5sec_micro_512_0000006360.mat
#
#
# saving ../synthetic_cloud_fields/WIZ_Clouds/BOMEX_1CLD_500CCN_10m_5sec/BOMEX_512x320_500CCN_10m_R100_invL_5sec_micro_512_0000006370.txt
# RE MIN = 1.0
# RE MAX = 15.767680168151855
# VE MIN = 0.019999999552965164
# VE MAX = 0.20000000298023224
# saving .mat file to: ../synthetic_cloud_fields/WIZ_Clouds/BOMEX_1CLD_500CCN_10m_5sec/BOMEX_512x320_500CCN_10m_R100_invL_5sec_micro_512_0000006370.mat
#
#
# saving ../synthetic_cloud_fields/WIZ_Clouds/BOMEX_1CLD_500CCN_10m_5sec/BOMEX_512x320_500CCN_10m_R100_invL_5sec_micro_512_0000006380.txt
# RE MIN = 1.0
# RE MAX = 15.52103328704834
# VE MIN = 0.019999999552965164
# VE MAX = 0.20000000298023224
# saving .mat file to: ../synthetic_cloud_fields/WIZ_Clouds/BOMEX_1CLD_500CCN_10m_5sec/BOMEX_512x320_500CCN_10m_R100_invL_5sec_micro_512_0000006380.mat
#
#
# saving ../synthetic_cloud_fields/WIZ_Clouds/BOMEX_1CLD_500CCN_10m_5sec/BOMEX_512x320_500CCN_10m_R100_invL_5sec_micro_512_0000006390.txt
# RE MIN = 1.0
# RE MAX = 15.357362747192383
# VE MIN = 0.019999999552965164
# VE MAX = 0.20000000298023224
# saving .mat file to: ../synthetic_cloud_fields/WIZ_Clouds/BOMEX_1CLD_500CCN_10m_5sec/BOMEX_512x320_500CCN_10m_R100_invL_5sec_micro_512_0000006390.mat
#
#
# saving ../synthetic_cloud_fields/WIZ_Clouds/BOMEX_1CLD_500CCN_10m_5sec/BOMEX_512x320_500CCN_10m_R100_invL_5sec_micro_512_0000006400.txt
# RE MIN = 1.0
# RE MAX = 15.995405197143555
# VE MIN = 0.019999999552965164
# VE MAX = 0.20000000298023224
# saving .mat file to: ../synthetic_cloud_fields/WIZ_Clouds/BOMEX_1CLD_500CCN_10m_5sec/BOMEX_512x320_500CCN_10m_R100_invL_5sec_micro_512_0000006400.mat
#
#
# saving ../synthetic_cloud_fields/WIZ_Clouds/BOMEX_1CLD_500CCN_10m_5sec/BOMEX_512x320_500CCN_10m_R100_invL_5sec_micro_512_0000006410.txt
# RE MIN = 1.0
# RE MAX = 15.9330472946167
# VE MIN = 0.019999999552965164
# VE MAX = 0.20000000298023224
# saving .mat file to: ../synthetic_cloud_fields/WIZ_Clouds/BOMEX_1CLD_500CCN_10m_5sec/BOMEX_512x320_500CCN_10m_R100_invL_5sec_micro_512_0000006410.mat
#
#
# saving ../synthetic_cloud_fields/WIZ_Clouds/BOMEX_1CLD_500CCN_10m_5sec/BOMEX_512x320_500CCN_10m_R100_invL_5sec_micro_512_0000006420.txt
# RE MIN = 1.0
# RE MAX = 15.926814079284668
# VE MIN = 0.019999999552965164
# VE MAX = 0.20000000298023224
# saving .mat file to: ../synthetic_cloud_fields/WIZ_Clouds/BOMEX_1CLD_500CCN_10m_5sec/BOMEX_512x320_500CCN_10m_R100_invL_5sec_micro_512_0000006420.mat
#
#
# saving ../synthetic_cloud_fields/WIZ_Clouds/BOMEX_1CLD_500CCN_10m_5sec/BOMEX_512x320_500CCN_10m_R100_invL_5sec_micro_512_0000006430.txt
# RE MIN = 1.0
# RE MAX = 16.20648765563965
# VE MIN = 0.019999999552965164
# VE MAX = 0.20000000298023224
# saving .mat file to: ../synthetic_cloud_fields/WIZ_Clouds/BOMEX_1CLD_500CCN_10m_5sec/BOMEX_512x320_500CCN_10m_R100_invL_5sec_micro_512_0000006430.mat
#
#
# saving ../synthetic_cloud_fields/WIZ_Clouds/BOMEX_1CLD_500CCN_10m_5sec/BOMEX_512x320_500CCN_10m_R100_invL_5sec_micro_512_0000006440.txt
# RE MIN = 1.0
# RE MAX = 16.39246940612793
# VE MIN = 0.019999999552965164
# VE MAX = 0.20000000298023224
# saving .mat file to: ../synthetic_cloud_fields/WIZ_Clouds/BOMEX_1CLD_500CCN_10m_5sec/BOMEX_512x320_500CCN_10m_R100_invL_5sec_micro_512_0000006440.mat
#
#
# saving ../synthetic_cloud_fields/WIZ_Clouds/BOMEX_1CLD_500CCN_10m_5sec/BOMEX_512x320_500CCN_10m_R100_invL_5sec_micro_512_0000006450.txt
# RE MIN = 1.0
# RE MAX = 16.487180709838867
# VE MIN = 0.019999999552965164
# VE MAX = 0.20000000298023224
# saving .mat file to: ../synthetic_cloud_fields/WIZ_Clouds/BOMEX_1CLD_500CCN_10m_5sec/BOMEX_512x320_500CCN_10m_R100_invL_5sec_micro_512_0000006450.mat
#
#
# saving ../synthetic_cloud_fields/WIZ_Clouds/BOMEX_1CLD_500CCN_10m_5sec/BOMEX_512x320_500CCN_10m_R100_invL_5sec_micro_512_0000006460.txt
# RE MIN = 1.0
# RE MAX = 15.622084617614746
# VE MIN = 0.019999999552965164
# VE MAX = 0.20000000298023224
# saving .mat file to: ../synthetic_cloud_fields/WIZ_Clouds/BOMEX_1CLD_500CCN_10m_5sec/BOMEX_512x320_500CCN_10m_R100_invL_5sec_micro_512_0000006460.mat
#
#
# saving ../synthetic_cloud_fields/WIZ_Clouds/BOMEX_1CLD_500CCN_10m_5sec/BOMEX_512x320_500CCN_10m_R100_invL_5sec_micro_512_0000006470.txt
# RE MIN = 1.0
# RE MAX = 15.540919303894043
# VE MIN = 0.019999999552965164
# VE MAX = 0.20000000298023224
# saving .mat file to: ../synthetic_cloud_fields/WIZ_Clouds/BOMEX_1CLD_500CCN_10m_5sec/BOMEX_512x320_500CCN_10m_R100_invL_5sec_micro_512_0000006470.mat
#
#
# saving ../synthetic_cloud_fields/WIZ_Clouds/BOMEX_1CLD_500CCN_10m_5sec/BOMEX_512x320_500CCN_10m_R100_invL_5sec_micro_512_0000006480.txt
# RE MIN = 1.0
# RE MAX = 15.537177085876465
# VE MIN = 0.019999999552965164
# VE MAX = 0.20000000298023224
# saving .mat file to: ../synthetic_cloud_fields/WIZ_Clouds/BOMEX_1CLD_500CCN_10m_5sec/BOMEX_512x320_500CCN_10m_R100_invL_5sec_micro_512_0000006480.mat
#
#
# saving ../synthetic_cloud_fields/WIZ_Clouds/BOMEX_1CLD_500CCN_10m_5sec/BOMEX_512x320_500CCN_10m_R100_invL_5sec_micro_512_0000006490.txt
# RE MIN = 1.0
# RE MAX = 15.45759105682373
# VE MIN = 0.019999999552965164
# VE MAX = 0.20000000298023224
# saving .mat file to: ../synthetic_cloud_fields/WIZ_Clouds/BOMEX_1CLD_500CCN_10m_5sec/BOMEX_512x320_500CCN_10m_R100_invL_5sec_micro_512_0000006490.mat
#
#
# saving ../synthetic_cloud_fields/WIZ_Clouds/BOMEX_1CLD_500CCN_10m_5sec/BOMEX_512x320_500CCN_10m_R100_invL_5sec_micro_512_0000006500.txt
# RE MIN = 1.0
# RE MAX = 15.478803634643555
# VE MIN = 0.019999999552965164
# VE MAX = 0.20000000298023224
# saving .mat file to: ../synthetic_cloud_fields/WIZ_Clouds/BOMEX_1CLD_500CCN_10m_5sec/BOMEX_512x320_500CCN_10m_R100_invL_5sec_micro_512_0000006500.mat
#
#
# saving ../synthetic_cloud_fields/WIZ_Clouds/BOMEX_1CLD_500CCN_10m_5sec/BOMEX_512x320_500CCN_10m_R100_invL_5sec_micro_512_0000006510.txt
# RE MIN = 1.0
# RE MAX = 18.1971378326416
# VE MIN = 0.019999999552965164
# VE MAX = 0.20000000298023224
# saving .mat file to: ../synthetic_cloud_fields/WIZ_Clouds/BOMEX_1CLD_500CCN_10m_5sec/BOMEX_512x320_500CCN_10m_R100_invL_5sec_micro_512_0000006510.mat
#
#
# saving ../synthetic_cloud_fields/WIZ_Clouds/BOMEX_1CLD_500CCN_10m_5sec/BOMEX_512x320_500CCN_10m_R100_invL_5sec_micro_512_0000006520.txt
# RE MIN = 1.0
# RE MAX = 16.070011138916016
# VE MIN = 0.019999999552965164
# VE MAX = 0.20000000298023224
# saving .mat file to: ../synthetic_cloud_fields/WIZ_Clouds/BOMEX_1CLD_500CCN_10m_5sec/BOMEX_512x320_500CCN_10m_R100_invL_5sec_micro_512_0000006520.mat
#
#
# saving ../synthetic_cloud_fields/WIZ_Clouds/BOMEX_1CLD_500CCN_10m_5sec/BOMEX_512x320_500CCN_10m_R100_invL_5sec_micro_512_0000006530.txt
# RE MIN = 1.0
# RE MAX = 15.82882022857666
# VE MIN = 0.019999999552965164
# VE MAX = 0.20000000298023224
# saving .mat file to: ../synthetic_cloud_fields/WIZ_Clouds/BOMEX_1CLD_500CCN_10m_5sec/BOMEX_512x320_500CCN_10m_R100_invL_5sec_micro_512_0000006530.mat
#
#
# saving ../synthetic_cloud_fields/WIZ_Clouds/BOMEX_1CLD_500CCN_10m_5sec/BOMEX_512x320_500CCN_10m_R100_invL_5sec_micro_512_0000006540.txt
# RE MIN = 1.0
# RE MAX = 15.936163902282715
# VE MIN = 0.019999999552965164
# VE MAX = 0.20000000298023224
# saving .mat file to: ../synthetic_cloud_fields/WIZ_Clouds/BOMEX_1CLD_500CCN_10m_5sec/BOMEX_512x320_500CCN_10m_R100_invL_5sec_micro_512_0000006540.mat
#
#
# saving ../synthetic_cloud_fields/WIZ_Clouds/BOMEX_1CLD_500CCN_10m_5sec/BOMEX_512x320_500CCN_10m_R100_invL_5sec_micro_512_0000006550.txt
# RE MIN = 1.0
# RE MAX = 16.491167068481445
# VE MIN = 0.019999999552965164
# VE MAX = 0.20000000298023224
# saving .mat file to: ../synthetic_cloud_fields/WIZ_Clouds/BOMEX_1CLD_500CCN_10m_5sec/BOMEX_512x320_500CCN_10m_R100_invL_5sec_micro_512_0000006550.mat
#
#
# saving ../synthetic_cloud_fields/WIZ_Clouds/BOMEX_1CLD_500CCN_10m_5sec/BOMEX_512x320_500CCN_10m_R100_invL_5sec_micro_512_0000006560.txt
# RE MIN = 1.0
# RE MAX = 15.880654335021973
# VE MIN = 0.019999999552965164
# VE MAX = 0.20000000298023224
# saving .mat file to: ../synthetic_cloud_fields/WIZ_Clouds/BOMEX_1CLD_500CCN_10m_5sec/BOMEX_512x320_500CCN_10m_R100_invL_5sec_micro_512_0000006560.mat
#
#
# saving ../synthetic_cloud_fields/WIZ_Clouds/BOMEX_1CLD_500CCN_10m_5sec/BOMEX_512x320_500CCN_10m_R100_invL_5sec_micro_512_0000006570.txt
# RE MIN = 1.0
# RE MAX = 15.888189315795898
# VE MIN = 0.019999999552965164
# VE MAX = 0.20000000298023224
# saving .mat file to: ../synthetic_cloud_fields/WIZ_Clouds/BOMEX_1CLD_500CCN_10m_5sec/BOMEX_512x320_500CCN_10m_R100_invL_5sec_micro_512_0000006570.mat
#
#
# saving ../synthetic_cloud_fields/WIZ_Clouds/BOMEX_1CLD_500CCN_10m_5sec/BOMEX_512x320_500CCN_10m_R100_invL_5sec_micro_512_0000006580.txt
# RE MIN = 1.0
# RE MAX = 16.4798526763916
# VE MIN = 0.019999999552965164
# VE MAX = 0.20000000298023224
# saving .mat file to: ../synthetic_cloud_fields/WIZ_Clouds/BOMEX_1CLD_500CCN_10m_5sec/BOMEX_512x320_500CCN_10m_R100_invL_5sec_micro_512_0000006580.mat
#
#
# saving ../synthetic_cloud_fields/WIZ_Clouds/BOMEX_1CLD_500CCN_10m_5sec/BOMEX_512x320_500CCN_10m_R100_invL_5sec_micro_512_0000006590.txt
# RE MIN = 1.0
# RE MAX = 17.068906784057617
# VE MIN = 0.019999999552965164
# VE MAX = 0.20000000298023224
# saving .mat file to: ../synthetic_cloud_fields/WIZ_Clouds/BOMEX_1CLD_500CCN_10m_5sec/BOMEX_512x320_500CCN_10m_R100_invL_5sec_micro_512_0000006590.mat
#
#
# saving ../synthetic_cloud_fields/WIZ_Clouds/BOMEX_1CLD_500CCN_10m_5sec/BOMEX_512x320_500CCN_10m_R100_invL_5sec_micro_512_0000006600.txt
# RE MIN = 1.0
# RE MAX = 16.112375259399414
# VE MIN = 0.019999999552965164
# VE MAX = 0.20000000298023224
# saving .mat file to: ../synthetic_cloud_fields/WIZ_Clouds/BOMEX_1CLD_500CCN_10m_5sec/BOMEX_512x320_500CCN_10m_R100_invL_5sec_micro_512_0000006600.mat
#
#
# saving ../synthetic_cloud_fields/WIZ_Clouds/BOMEX_1CLD_500CCN_10m_5sec/BOMEX_512x320_500CCN_10m_R100_invL_5sec_micro_512_0000006610.txt
# RE MIN = 1.0
# RE MAX = 17.55771827697754
# VE MIN = 0.019999999552965164
# VE MAX = 0.20000000298023224
# saving .mat file to: ../synthetic_cloud_fields/WIZ_Clouds/BOMEX_1CLD_500CCN_10m_5sec/BOMEX_512x320_500CCN_10m_R100_invL_5sec_micro_512_0000006610.mat
#
#
# saving ../synthetic_cloud_fields/WIZ_Clouds/BOMEX_1CLD_500CCN_10m_5sec/BOMEX_512x320_500CCN_10m_R100_invL_5sec_micro_512_0000006620.txt
# RE MIN = 1.0
# RE MAX = 16.459524154663086
# VE MIN = 0.019999999552965164
# VE MAX = 0.20000000298023224
# saving .mat file to: ../synthetic_cloud_fields/WIZ_Clouds/BOMEX_1CLD_500CCN_10m_5sec/BOMEX_512x320_500CCN_10m_R100_invL_5sec_micro_512_0000006620.mat
#
#
# saving ../synthetic_cloud_fields/WIZ_Clouds/BOMEX_1CLD_500CCN_10m_5sec/BOMEX_512x320_500CCN_10m_R100_invL_5sec_micro_512_0000006630.txt
# RE MIN = 1.0
# RE MAX = 16.129182815551758
# VE MIN = 0.019999999552965164
# VE MAX = 0.20000000298023224
# saving .mat file to: ../synthetic_cloud_fields/WIZ_Clouds/BOMEX_1CLD_500CCN_10m_5sec/BOMEX_512x320_500CCN_10m_R100_invL_5sec_micro_512_0000006630.mat
#
#
# saving ../synthetic_cloud_fields/WIZ_Clouds/BOMEX_1CLD_500CCN_10m_5sec/BOMEX_512x320_500CCN_10m_R100_invL_5sec_micro_512_0000006640.txt
# RE MIN = 1.0
# RE MAX = 16.705976486206055
# VE MIN = 0.019999999552965164
# VE MAX = 0.20000000298023224
# saving .mat file to: ../synthetic_cloud_fields/WIZ_Clouds/BOMEX_1CLD_500CCN_10m_5sec/BOMEX_512x320_500CCN_10m_R100_invL_5sec_micro_512_0000006640.mat
#
#
# saving ../synthetic_cloud_fields/WIZ_Clouds/BOMEX_1CLD_500CCN_10m_5sec/BOMEX_512x320_500CCN_10m_R100_invL_5sec_micro_512_0000006650.txt
# RE MIN = 1.0
# RE MAX = 16.334213256835938
# VE MIN = 0.019999999552965164
# VE MAX = 0.20000000298023224
# saving .mat file to: ../synthetic_cloud_fields/WIZ_Clouds/BOMEX_1CLD_500CCN_10m_5sec/BOMEX_512x320_500CCN_10m_R100_invL_5sec_micro_512_0000006650.mat
#
#
# saving ../synthetic_cloud_fields/WIZ_Clouds/BOMEX_1CLD_500CCN_10m_5sec/BOMEX_512x320_500CCN_10m_R100_invL_5sec_micro_512_0000006660.txt
# RE MIN = 1.0
# RE MAX = 16.053377151489258
# VE MIN = 0.019999999552965164
# VE MAX = 0.20000000298023224
# saving .mat file to: ../synthetic_cloud_fields/WIZ_Clouds/BOMEX_1CLD_500CCN_10m_5sec/BOMEX_512x320_500CCN_10m_R100_invL_5sec_micro_512_0000006660.mat
#
#
# saving ../synthetic_cloud_fields/WIZ_Clouds/BOMEX_1CLD_500CCN_10m_5sec/BOMEX_512x320_500CCN_10m_R100_invL_5sec_micro_512_0000006670.txt
# RE MIN = 1.0
# RE MAX = 16.033489227294922
# VE MIN = 0.019999999552965164
# VE MAX = 0.20000000298023224
# saving .mat file to: ../synthetic_cloud_fields/WIZ_Clouds/BOMEX_1CLD_500CCN_10m_5sec/BOMEX_512x320_500CCN_10m_R100_invL_5sec_micro_512_0000006670.mat
#
#
# saving ../synthetic_cloud_fields/WIZ_Clouds/BOMEX_1CLD_500CCN_10m_5sec/BOMEX_512x320_500CCN_10m_R100_invL_5sec_micro_512_0000006680.txt
# RE MIN = 1.0
# RE MAX = 16.095905303955078
# VE MIN = 0.019999999552965164
# VE MAX = 0.20000000298023224
# saving .mat file to: ../synthetic_cloud_fields/WIZ_Clouds/BOMEX_1CLD_500CCN_10m_5sec/BOMEX_512x320_500CCN_10m_R100_invL_5sec_micro_512_0000006680.mat
#
#
# saving ../synthetic_cloud_fields/WIZ_Clouds/BOMEX_1CLD_500CCN_10m_5sec/BOMEX_512x320_500CCN_10m_R100_invL_5sec_micro_512_0000006690.txt
# RE MIN = 1.0
# RE MAX = 16.11685562133789
# VE MIN = 0.019999999552965164
# VE MAX = 0.20000000298023224
# saving .mat file to: ../synthetic_cloud_fields/WIZ_Clouds/BOMEX_1CLD_500CCN_10m_5sec/BOMEX_512x320_500CCN_10m_R100_invL_5sec_micro_512_0000006690.mat
#
#
# saving ../synthetic_cloud_fields/WIZ_Clouds/BOMEX_1CLD_500CCN_10m_5sec/BOMEX_512x320_500CCN_10m_R100_invL_5sec_micro_512_0000006700.txt
# RE MIN = 1.0
# RE MAX = 17.4425106048584
# VE MIN = 0.019999999552965164
# VE MAX = 0.20000000298023224
# saving .mat file to: ../synthetic_cloud_fields/WIZ_Clouds/BOMEX_1CLD_500CCN_10m_5sec/BOMEX_512x320_500CCN_10m_R100_invL_5sec_micro_512_0000006700.mat
#
#
# saving ../synthetic_cloud_fields/WIZ_Clouds/BOMEX_1CLD_500CCN_10m_5sec/BOMEX_512x320_500CCN_10m_R100_invL_5sec_micro_512_0000006710.txt
# RE MIN = 1.0
# RE MAX = 16.739871978759766
# VE MIN = 0.019999999552965164
# VE MAX = 0.20000000298023224
# saving .mat file to: ../synthetic_cloud_fields/WIZ_Clouds/BOMEX_1CLD_500CCN_10m_5sec/BOMEX_512x320_500CCN_10m_R100_invL_5sec_micro_512_0000006710.mat
#
#
# saving ../synthetic_cloud_fields/WIZ_Clouds/BOMEX_1CLD_500CCN_10m_5sec/BOMEX_512x320_500CCN_10m_R100_invL_5sec_micro_512_0000006720.txt
# RE MIN = 1.0
# RE MAX = 16.163829803466797
# VE MIN = 0.019999999552965164
# VE MAX = 0.20000000298023224
# saving .mat file to: ../synthetic_cloud_fields/WIZ_Clouds/BOMEX_1CLD_500CCN_10m_5sec/BOMEX_512x320_500CCN_10m_R100_invL_5sec_micro_512_0000006720.mat
#
#
# saving ../synthetic_cloud_fields/WIZ_Clouds/BOMEX_1CLD_500CCN_10m_5sec/BOMEX_512x320_500CCN_10m_R100_invL_5sec_micro_512_0000006730.txt
# RE MIN = 1.0
# RE MAX = 18.469776153564453
# VE MIN = 0.019999999552965164
# VE MAX = 0.20000000298023224
# saving .mat file to: ../synthetic_cloud_fields/WIZ_Clouds/BOMEX_1CLD_500CCN_10m_5sec/BOMEX_512x320_500CCN_10m_R100_invL_5sec_micro_512_0000006730.mat
#
#
# saving ../synthetic_cloud_fields/WIZ_Clouds/BOMEX_1CLD_500CCN_10m_5sec/BOMEX_512x320_500CCN_10m_R100_invL_5sec_micro_512_0000006740.txt
# RE MIN = 1.0
# RE MAX = 18.302967071533203
# VE MIN = 0.019999999552965164
# VE MAX = 0.20000000298023224
# saving .mat file to: ../synthetic_cloud_fields/WIZ_Clouds/BOMEX_1CLD_500CCN_10m_5sec/BOMEX_512x320_500CCN_10m_R100_invL_5sec_micro_512_0000006740.mat
#
#
# saving ../synthetic_cloud_fields/WIZ_Clouds/BOMEX_1CLD_500CCN_10m_5sec/BOMEX_512x320_500CCN_10m_R100_invL_5sec_micro_512_0000006750.txt
# RE MIN = 1.0
# RE MAX = 17.194019317626953
# VE MIN = 0.019999999552965164
# VE MAX = 0.20000000298023224
# saving .mat file to: ../synthetic_cloud_fields/WIZ_Clouds/BOMEX_1CLD_500CCN_10m_5sec/BOMEX_512x320_500CCN_10m_R100_invL_5sec_micro_512_0000006750.mat
#
#
# saving ../synthetic_cloud_fields/WIZ_Clouds/BOMEX_1CLD_500CCN_10m_5sec/BOMEX_512x320_500CCN_10m_R100_invL_5sec_micro_512_0000006760.txt
# RE MIN = 1.0
# RE MAX = 17.11428451538086
# VE MIN = 0.019999999552965164
# VE MAX = 0.20000000298023224
# saving .mat file to: ../synthetic_cloud_fields/WIZ_Clouds/BOMEX_1CLD_500CCN_10m_5sec/BOMEX_512x320_500CCN_10m_R100_invL_5sec_micro_512_0000006760.mat
#
#
# saving ../synthetic_cloud_fields/WIZ_Clouds/BOMEX_1CLD_500CCN_10m_5sec/BOMEX_512x320_500CCN_10m_R100_invL_5sec_micro_512_0000006770.txt
# RE MIN = 1.0
# RE MAX = 16.419157028198242
# VE MIN = 0.019999999552965164
# VE MAX = 0.20000000298023224
# saving .mat file to: ../synthetic_cloud_fields/WIZ_Clouds/BOMEX_1CLD_500CCN_10m_5sec/BOMEX_512x320_500CCN_10m_R100_invL_5sec_micro_512_0000006770.mat
#
#
# saving ../synthetic_cloud_fields/WIZ_Clouds/BOMEX_1CLD_500CCN_10m_5sec/BOMEX_512x320_500CCN_10m_R100_invL_5sec_micro_512_0000006780.txt
# RE MIN = 1.0
# RE MAX = 16.40594482421875
# VE MIN = 0.019999999552965164
# VE MAX = 0.20000000298023224
# saving .mat file to: ../synthetic_cloud_fields/WIZ_Clouds/BOMEX_1CLD_500CCN_10m_5sec/BOMEX_512x320_500CCN_10m_R100_invL_5sec_micro_512_0000006780.mat
#
#
# saving ../synthetic_cloud_fields/WIZ_Clouds/BOMEX_1CLD_500CCN_10m_5sec/BOMEX_512x320_500CCN_10m_R100_invL_5sec_micro_512_0000006790.txt
# RE MIN = 1.0
# RE MAX = 16.17501449584961
# VE MIN = 0.019999999552965164
# VE MAX = 0.20000000298023224
# saving .mat file to: ../synthetic_cloud_fields/WIZ_Clouds/BOMEX_1CLD_500CCN_10m_5sec/BOMEX_512x320_500CCN_10m_R100_invL_5sec_micro_512_0000006790.mat
#
#
# saving ../synthetic_cloud_fields/WIZ_Clouds/BOMEX_1CLD_500CCN_10m_5sec/BOMEX_512x320_500CCN_10m_R100_invL_5sec_micro_512_0000006800.txt
# RE MIN = 1.0
# RE MAX = 16.192171096801758
# VE MIN = 0.019999999552965164
# VE MAX = 0.20000000298023224
# saving .mat file to: ../synthetic_cloud_fields/WIZ_Clouds/BOMEX_1CLD_500CCN_10m_5sec/BOMEX_512x320_500CCN_10m_R100_invL_5sec_micro_512_0000006800.mat
#
#
# saving ../synthetic_cloud_fields/WIZ_Clouds/BOMEX_1CLD_500CCN_10m_5sec/BOMEX_512x320_500CCN_10m_R100_invL_5sec_micro_512_0000006810.txt
# RE MIN = 1.0
# RE MAX = 16.071393966674805
# VE MIN = 0.019999999552965164
# VE MAX = 0.20000000298023224
# saving .mat file to: ../synthetic_cloud_fields/WIZ_Clouds/BOMEX_1CLD_500CCN_10m_5sec/BOMEX_512x320_500CCN_10m_R100_invL_5sec_micro_512_0000006810.mat
#
#
# saving ../synthetic_cloud_fields/WIZ_Clouds/BOMEX_1CLD_500CCN_10m_5sec/BOMEX_512x320_500CCN_10m_R100_invL_5sec_micro_512_0000006820.txt
# RE MIN = 1.0
# RE MAX = 18.21495819091797
# VE MIN = 0.019999999552965164
# VE MAX = 0.20000000298023224
# saving .mat file to: ../synthetic_cloud_fields/WIZ_Clouds/BOMEX_1CLD_500CCN_10m_5sec/BOMEX_512x320_500CCN_10m_R100_invL_5sec_micro_512_0000006820.mat
#
#
# saving ../synthetic_cloud_fields/WIZ_Clouds/BOMEX_1CLD_500CCN_10m_5sec/BOMEX_512x320_500CCN_10m_R100_invL_5sec_micro_512_0000006830.txt
# RE MIN = 1.0
# RE MAX = 16.333534240722656
# VE MIN = 0.019999999552965164
# VE MAX = 0.20000000298023224
# saving .mat file to: ../synthetic_cloud_fields/WIZ_Clouds/BOMEX_1CLD_500CCN_10m_5sec/BOMEX_512x320_500CCN_10m_R100_invL_5sec_micro_512_0000006830.mat
#
#
# saving ../synthetic_cloud_fields/WIZ_Clouds/BOMEX_1CLD_500CCN_10m_5sec/BOMEX_512x320_500CCN_10m_R100_invL_5sec_micro_512_0000006840.txt
# RE MIN = 1.0
# RE MAX = 16.536697387695312
# VE MIN = 0.019999999552965164
# VE MAX = 0.20000000298023224
# saving .mat file to: ../synthetic_cloud_fields/WIZ_Clouds/BOMEX_1CLD_500CCN_10m_5sec/BOMEX_512x320_500CCN_10m_R100_invL_5sec_micro_512_0000006840.mat
#
#
# saving ../synthetic_cloud_fields/WIZ_Clouds/BOMEX_1CLD_500CCN_10m_5sec/BOMEX_512x320_500CCN_10m_R100_invL_5sec_micro_512_0000006850.txt
# RE MIN = 1.0
# RE MAX = 16.63360595703125
# VE MIN = 0.019999999552965164
# VE MAX = 0.20000000298023224
# saving .mat file to: ../synthetic_cloud_fields/WIZ_Clouds/BOMEX_1CLD_500CCN_10m_5sec/BOMEX_512x320_500CCN_10m_R100_invL_5sec_micro_512_0000006850.mat
#
#
# saving ../synthetic_cloud_fields/WIZ_Clouds/BOMEX_1CLD_500CCN_10m_5sec/BOMEX_512x320_500CCN_10m_R100_invL_5sec_micro_512_0000006860.txt
# RE MIN = 1.0
# RE MAX = 18.357282638549805
# VE MIN = 0.019999999552965164
# VE MAX = 0.20000000298023224
# saving .mat file to: ../synthetic_cloud_fields/WIZ_Clouds/BOMEX_1CLD_500CCN_10m_5sec/BOMEX_512x320_500CCN_10m_R100_invL_5sec_micro_512_0000006860.mat
#
#
# saving ../synthetic_cloud_fields/WIZ_Clouds/BOMEX_1CLD_500CCN_10m_5sec/BOMEX_512x320_500CCN_10m_R100_invL_5sec_micro_512_0000006870.txt
# RE MIN = 1.0
# RE MAX = 16.603696823120117
# VE MIN = 0.019999999552965164
# VE MAX = 0.20000000298023224
# saving .mat file to: ../synthetic_cloud_fields/WIZ_Clouds/BOMEX_1CLD_500CCN_10m_5sec/BOMEX_512x320_500CCN_10m_R100_invL_5sec_micro_512_0000006870.mat
#
#
# saving ../synthetic_cloud_fields/WIZ_Clouds/BOMEX_1CLD_500CCN_10m_5sec/BOMEX_512x320_500CCN_10m_R100_invL_5sec_micro_512_0000006880.txt
# RE MIN = 1.0
# RE MAX = 17.250686645507812
# VE MIN = 0.019999999552965164
# VE MAX = 0.20000000298023224
# saving .mat file to: ../synthetic_cloud_fields/WIZ_Clouds/BOMEX_1CLD_500CCN_10m_5sec/BOMEX_512x320_500CCN_10m_R100_invL_5sec_micro_512_0000006880.mat
#
#
# saving ../synthetic_cloud_fields/WIZ_Clouds/BOMEX_1CLD_500CCN_10m_5sec/BOMEX_512x320_500CCN_10m_R100_invL_5sec_micro_512_0000006890.txt
# RE MIN = 1.0
# RE MAX = 16.74484634399414
# VE MIN = 0.019999999552965164
# VE MAX = 0.20000000298023224
# saving .mat file to: ../synthetic_cloud_fields/WIZ_Clouds/BOMEX_1CLD_500CCN_10m_5sec/BOMEX_512x320_500CCN_10m_R100_invL_5sec_micro_512_0000006890.mat
#
#
# saving ../synthetic_cloud_fields/WIZ_Clouds/BOMEX_1CLD_500CCN_10m_5sec/BOMEX_512x320_500CCN_10m_R100_invL_5sec_micro_512_0000006900.txt
# RE MIN = 1.0
# RE MAX = 16.847793579101562
# VE MIN = 0.019999999552965164
# VE MAX = 0.20000000298023224
# saving .mat file to: ../synthetic_cloud_fields/WIZ_Clouds/BOMEX_1CLD_500CCN_10m_5sec/BOMEX_512x320_500CCN_10m_R100_invL_5sec_micro_512_0000006900.mat
#
#
# saving ../synthetic_cloud_fields/WIZ_Clouds/BOMEX_1CLD_500CCN_10m_5sec/BOMEX_512x320_500CCN_10m_R100_invL_5sec_micro_512_0000006910.txt
# RE MIN = 1.0
# RE MAX = 17.228063583374023
# VE MIN = 0.019999999552965164
# VE MAX = 0.20000000298023224
# saving .mat file to: ../synthetic_cloud_fields/WIZ_Clouds/BOMEX_1CLD_500CCN_10m_5sec/BOMEX_512x320_500CCN_10m_R100_invL_5sec_micro_512_0000006910.mat
#
#
# saving ../synthetic_cloud_fields/WIZ_Clouds/BOMEX_1CLD_500CCN_10m_5sec/BOMEX_512x320_500CCN_10m_R100_invL_5sec_micro_512_0000006920.txt
# RE MIN = 1.0
# RE MAX = 17.021320343017578
# VE MIN = 0.019999999552965164
# VE MAX = 0.20000000298023224
# saving .mat file to: ../synthetic_cloud_fields/WIZ_Clouds/BOMEX_1CLD_500CCN_10m_5sec/BOMEX_512x320_500CCN_10m_R100_invL_5sec_micro_512_0000006920.mat
#
#
# saving ../synthetic_cloud_fields/WIZ_Clouds/BOMEX_1CLD_500CCN_10m_5sec/BOMEX_512x320_500CCN_10m_R100_invL_5sec_micro_512_0000006930.txt
# RE MIN = 1.0
# RE MAX = 16.932785034179688
# VE MIN = 0.019999999552965164
# VE MAX = 0.20000000298023224
# saving .mat file to: ../synthetic_cloud_fields/WIZ_Clouds/BOMEX_1CLD_500CCN_10m_5sec/BOMEX_512x320_500CCN_10m_R100_invL_5sec_micro_512_0000006930.mat
#
#
# saving ../synthetic_cloud_fields/WIZ_Clouds/BOMEX_1CLD_500CCN_10m_5sec/BOMEX_512x320_500CCN_10m_R100_invL_5sec_micro_512_0000006940.txt
# RE MIN = 1.0
# RE MAX = 16.90403175354004
# VE MIN = 0.019999999552965164
# VE MAX = 0.20000000298023224
# saving .mat file to: ../synthetic_cloud_fields/WIZ_Clouds/BOMEX_1CLD_500CCN_10m_5sec/BOMEX_512x320_500CCN_10m_R100_invL_5sec_micro_512_0000006940.mat
#
#
# saving ../synthetic_cloud_fields/WIZ_Clouds/BOMEX_1CLD_500CCN_10m_5sec/BOMEX_512x320_500CCN_10m_R100_invL_5sec_micro_512_0000006950.txt
# RE MIN = 1.0
# RE MAX = 17.23937225341797
# VE MIN = 0.019999999552965164
# VE MAX = 0.20000000298023224
# saving .mat file to: ../synthetic_cloud_fields/WIZ_Clouds/BOMEX_1CLD_500CCN_10m_5sec/BOMEX_512x320_500CCN_10m_R100_invL_5sec_micro_512_0000006950.mat
#
#
# saving ../synthetic_cloud_fields/WIZ_Clouds/BOMEX_1CLD_500CCN_10m_5sec/BOMEX_512x320_500CCN_10m_R100_invL_5sec_micro_512_0000006960.txt
# RE MIN = 1.0
# RE MAX = 17.134136199951172
# VE MIN = 0.019999999552965164
# VE MAX = 0.20000000298023224
# saving .mat file to: ../synthetic_cloud_fields/WIZ_Clouds/BOMEX_1CLD_500CCN_10m_5sec/BOMEX_512x320_500CCN_10m_R100_invL_5sec_micro_512_0000006960.mat
#
#
# saving ../synthetic_cloud_fields/WIZ_Clouds/BOMEX_1CLD_500CCN_10m_5sec/BOMEX_512x320_500CCN_10m_R100_invL_5sec_micro_512_0000006970.txt
# RE MIN = 1.0
# RE MAX = 18.055633544921875
# VE MIN = 0.019999999552965164
# VE MAX = 0.20000000298023224
# saving .mat file to: ../synthetic_cloud_fields/WIZ_Clouds/BOMEX_1CLD_500CCN_10m_5sec/BOMEX_512x320_500CCN_10m_R100_invL_5sec_micro_512_0000006970.mat
#
#
# saving ../synthetic_cloud_fields/WIZ_Clouds/BOMEX_1CLD_500CCN_10m_5sec/BOMEX_512x320_500CCN_10m_R100_invL_5sec_micro_512_0000006980.txt
# RE MIN = 1.0
# RE MAX = 17.189237594604492
# VE MIN = 0.019999999552965164
# VE MAX = 0.20000000298023224
# saving .mat file to: ../synthetic_cloud_fields/WIZ_Clouds/BOMEX_1CLD_500CCN_10m_5sec/BOMEX_512x320_500CCN_10m_R100_invL_5sec_micro_512_0000006980.mat
